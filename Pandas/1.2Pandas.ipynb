# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":['abhishek', 'akash', 'sarthak', 'krishna kant'],
    "marks":[92, 34, 56 ,89],
    "city":['Pilibhit', 'javalpur', 'noida', 'lucknow']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#            name  marks      city
# 0      abhishek     92  Pilibhit
# 1         akash     34  javalpur
# 2       sarthak     56     noida
# 3  krishna kant     89   lucknow

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends2.csv', index = False)

# %%
df.head(2)
# Out:
#        name  marks      city
# 0  abhishek     92  Pilibhit
# 1     akash     34  javalpur

# %%
df.tail(2)
# Out:
#            name  marks     city
# 2       sarthak     56    noida
# 3  krishna kant     89  lucknow

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   67.750000
# std    27.789386
# min    34.000000
# 25%    50.500000
# 50%    72.500000
# 75%    89.750000
# max    92.000000

# %%
train = pd.read_csv('train.csv')

# %%
train
# Out:
#    train no.  marks      city
# 0        434     67  Pilibhit
# 1       4345     34  javalpur
# 2       3454     56     noida
# 3       8678     89   lucknow

# %%
train['marks'][0] = 67
# Out:
# C:\Users\ABHISH~1\AppData\Local\Temp/ipykernel_9980/2345586932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['marks'][0] = 67

# %%
train
# Out:
#    train no.  marks      city
# 0        434     67  Pilibhit
# 1       4345     34  javalpur
# 2       3454     56     noida
# 3       8678     89   lucknow

# %%
train.to_csv('train.csv', index=False)

# %%
train.index = ['first', 'second', 'third', 'fourth']
train
# Out:
#         train no.  marks      city
# first         434     67  Pilibhit
# second       4345     34  javalpur
# third        3454     56     noida
# fourth       8678     89   lucknow

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.765235
# 1     0.024703
# 2     0.675373
# 3     0.196186
# 4     0.993137
# 5     0.258856
# 6     0.429499
# 7     0.206861
# 8     0.110103
# 9     0.425762
# 10    0.889417
# 11    0.915567
# 12    0.850543
# 13    0.008377
# 14    0.276605
# 15    0.552300
# 16    0.087527
# 17    0.613546
# 18    0.091895
# 19    0.398510
# 20    0.225048
# 21    0.512123
# 22    0.763223
# 23    0.125915
# 24    0.273377
# 25    0.788899
# 26    0.731423
# 27    0.809468
# 28    0.639292
# 29    0.304945
# 30    0.563649
# 31    0.149275
# 32    0.600487
# 33    0.042990
# dtype: float64

# %%
newdf = pd.DataFrame(np.random.rand(334,5))
newdf.head(5)
# Out:
#           0         1         2         3         4
# 0  0.012801  0.639054  0.809774  0.229538  0.839506
# 1  0.812464  0.161315  0.264984  0.263470  0.508430
# 2  0.366081  0.493460  0.313222  0.187139  0.567784
# 3  0.975959  0.280259  0.044888  0.345153  0.164323
# 4  0.762722  0.833899  0.921685  0.842752  0.379521

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.463640    0.479003    0.515822    0.502229    0.491961
# std      0.282783    0.287456    0.289029    0.289411    0.285447
# min      0.001014    0.006732    0.000800    0.008105    0.001392
# 25%      0.207151    0.221136    0.272996    0.248202    0.255439
# 50%      0.450731    0.481376    0.518243    0.496295    0.517311
# 75%      0.710773    0.735365    0.758587    0.748104    0.736764
# max      0.994171    0.999862    0.998004    0.998741    0.990985

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.index
# Out:
# RangeIndex(start=0, stop=334, step=1)

# %%
newdf.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
newdf.to_numpy()
# Out:
# array([[0.01280111, 0.63905386, 0.80977405, 0.22953833, 0.83950559],
#        [0.81246445, 0.16131464, 0.26498421, 0.26347022, 0.50843019],
#        [0.36608101, 0.49345977, 0.31322171, 0.18713906, 0.56778371],
#        ...,
#        [0.11079591, 0.13106021, 0.27313293, 0.78659666, 0.16424853],
#        [0.05836803, 0.78288149, 0.2948058 , 0.22959894, 0.69353517],
#        [0.4490512 , 0.18653932, 0.6812949 , 0.37136465, 0.37759127]])

# %%
newdf.T
# Out:
#         0         1         2         3         4         5         6    \
# 0  0
                  'C' : [23, 35, np.nan],
                  'D' : [np.nan, np.nan, None]})

# %%
df
# Out:
#      A    B     C   D
# 0  bat  abc  23.0 NaN
# 1  foo  bar  35.0 NaN
# 2  bat  xyz   NaN NaN

# %%
df.dropna(how = 'all', axis = 1)
# Out:
#      A    B     C
# 0  bat  abc  23.0
# 1  foo  bar  35.0
# 2  bat  xyz   NaN

# %%
df
# Out:
#      A    B     C   D
# 0  bat  abc  23.0 NaN
# 1  foo  bar  35.0 NaN
# 2  bat  xyz   NaN NaN

# %%
df.drop_duplicates(subset = ['A'], keep = 'last')
# Out:
#      A    B     C   D
# 1  foo  bar  35.0 NaN
# 2  bat  xyz   NaN NaN

# %%
df.drop_duplicates(subset = ['A'], keep = 'first')
# Out:
#      A    B     C   D
# 0  bat  abc  23.0 NaN
# 1  foo  bar  35.0 NaN

# %%
df.drop_duplicates(subset = ['A'], keep = 0)
# Out:
#      A    B     C   D
# 1  foo  bar  35.0 NaN

# %%
df.shape
# Out:
# (3, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      object
#  1   B       3 non-null      object
#  2   C       2 non-null      float64
#  3   D       0 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 224.0+ bytes

# %%
df['A'].value_counts(dropna=0)
# Out:
# bat    2
# foo    1
# Name: A, dtype: int64

# %%
df.notnull()
# Out:
#       A     B      C      D
# 0  True  True   True  False
# 1  True  True   True  False
# 2  True  True  False  False

# %%
df.isnull()
# Out:
#        A      B      C     D
# 0  False  False  False  True
# 1  False  False  False  True
# 2  False  False   True  True

# %%
df.describe()
# Out:
#                C    D
# count   2.000000  0.0
# mean   29.000000  NaN
# std     8.485281  NaN
# min    23.000000  NaN
# 25%    26.000000  NaN
# 50%    29.000000  NaN
# 75%    32.000000  NaN
# max    35.000000  NaN

# %%
df = pd.DataFrame([('Foreign Cinema', 'Restaurant', 289.0),
                   ('Liho Liho', 'Restaurant', 224.0),
                   ('500 Club', 'bar', 80.5),
                   ('The Square', 'bar', np.nan)],
           columns=('name', 'type', 'AvgBill')
                 )

# %%
df
# Out:
#              name        type  AvgBill
# 0  Foreign Cinema  Restaurant    289.0
# 1       Liho Liho  Restaurant    224.0
# 2        500 Club         bar     80.5
# 3      The Square         bar      NaN

# %%
df['AvgBill'].mean()
# Out:
# 197.83333333333334

# %%
df.count()
# Out:
# name       4
# type       4
# AvgBill    3
# dtype: int64

# %%
df['AvgBill'].max()
# Out:
# 289.0

# %%
df.median(numeric_only=True)
# Out:
# AvgBill    224.0
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# AvgBill    106.684504
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(6,4), index= dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.379771  0.576380  0.621295  0.665646
# 2013-01-02  0.522215  0.241652  0.912290  0.656791
# 2013-01-03  0.743411  0.916180  0.391101  0.312241
# 2013-01-04  0.839134  0.149718  0.839088  0.186306
# 2013-01-05  0.266936  0.919030  0.778118  0.607968
# 2013-01-06  0.599827  0.707844  0.575632  0.560240

# %%
df = pd.DataFrame({'A':1.0,
                   'B':pd.Timestamp('20200901'),
                   'C':pd.Series(1,index = list(range(0,5)), dtype='float32'),
                   'D':np.array([3]*5,dtype='int32'),
                   'E':pd.Categorical(['Train','Bus','Car','Bike','Cycle']),
                   'F':'Foo'})

# %%
# df2 = pd.DataFrame({'A': 1.,
#    ...:                     'B': pd.Timestamp('20130102'),
#    ...:                     'C': pd.Series(1, index=list(range(4)), dtype='float32'),
#    ...:                     'D': np.array([3] * 4, dtype='int32'),
#    ...:                     'E': pd.Categorical(["test", "train", "test", "train"]),
#    ...:                     'F': 'foo'})

# %%
df
# Out:
#      A          B    C  D      E    F
# 0  1.0 2020-09-01  1.0  3  Train  Foo
# 1  1.0 2020-09-01  1.0  3    Bus  Foo
# 2  1.0 2020-09-01  1.0  3    Car  Foo
# 3  1.0 2020-09-01  1.0  3   Bike  Foo
# 4  1.0 2020-09-01  1.0  3  Cycle  Foo

# %%
df.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object
