# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df2 = pd.read_excel('Analysed_KPMG_VI_New_raw_data_update_final.xlsx', sheet_name='CustomerDemographic', usecols='A:M')

# %%
df2.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB   Age  \
# 0                                   93 1953-10-12  67.0
# 1                                   81 1980-12-16  40.0
# 2                                   61 1954-01-20  67.0
# 3                                   33 1961-10-03  59.0
# 4                                   56 1977-05-13  44.0
#
#                 job_title job_industry_category     wealth_segment  \
# 0     Executive Secretary                Health      Mass Customer
# 1  Administrative Officer    Financial Services      Mass Customer
# 2      Recruiting Manager              Property      Mass Customer
# ...

# %%
a= df2['Age'].values

sns.set(rc={'figure.figsize' :(12,10)})
sns.boxplot(a)
# Out:
# C:\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
df2['Age'].median()
# Out:
# 44.0

# %%
sns.boxplot(x='job_industry_category', y= 'past_3_years_bike_related_purchases', data = df2)
# Out:
# <AxesSubplot:xlabel='job_industry_category', ylabel='past_3_years_bike_related_purchases'>

# %%
sns.boxplot(y='job_industry_category', x= 'past_3_years_bike_related_purchases', data = df2, color='#5ED4F9')
# Out:
# <AxesSubplot:xlabel='past_3_years_bike_related_purchases', ylabel='job_industry_category'>

# %%
sns.boxplot(x='job_industry_category', y= 'past_3_years_bike_related_purchases', hue='gender' ,data = df2, color='#5ED4F9')
# Out:
# <AxesSubplot:xlabel='job_industry_category', ylabel='past_3_years_bike_related_purchases'>

# %%
sns.boxplot(x='job_industry_category', y= 'past_3_years_bike_related_purchases', data = df2, color= '#EDF95E')
sns.lineplot(x='job_industry_category', y= 'past_3_years_bike_related_purchases', data = df2, color= 'red')
# Out:
# <AxesSubplot:xlabel='job_industry_category', ylabel='past_3_years_bike_related_purchases'>

# %%
sns.boxplot(x='job_industry_category', y= 'past_3_years_bike_related_purchases', data = df2, color= '#EDF95E')
sns.swarmplot(x='job_industry_category', y= 'past_3_years_bike_related_purchases', data = df2, color= 'red')
# Out:
# <AxesSubplot:xlabel='job_industry_category', ylabel='past_3_years_bike_related_purchases'>

# %%
df2.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'Age', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure'],
#       dtype='object')

# %%
sns.scatterplot(x='past_3_years_bike_related_purchases', y= 'Age', data = df2, color= 'c')
# Out:
# <AxesSubplot:xlabel='past_3_years_bike_related_purchases', ylabel='Age'>

# %%
a = sns.scatterplot(x='Age', y='past_3_years_bike_related_purchases',hue='wealth_segment', style='wealth_segment',data=df2)

# %%
a = sns.scatterplot(x='Age', y='past_3_years_bike_related_purchases',hue='wealth_segment', style='wealth_segment',data=df2 ,size ='customer_id', sizes =(20,200))

# %%
a = sns.scatterplot(x='Age', y='past_3_years_bike_related_purchases',hue='wealth_segment',data=df2 ,size ='customer_id', sizes =(20,200))

# %% [markdown]
# ## Lm Plots

# %%
sns.lmplot(x='past_3_years_bike_related_purchases', y= 'Age', data = df2, height=10)
# to learn about how it works( cost function MSE) https://towardsdatascience.com/machine-learning-fundamentals-via-linear-regression-41a5d11f5220

# %%
sns.lmplot(x='past_3_years_bike_related_purchases', y= 'Age', hue='gender', data = df2, height=10, markers=['o','+','x'])

# %%
sns.lmplot(x='past_3_years_bike_related_purchases', y= 'Age', col='gender', data = df2, height=10, line_kws = ({'color':'red'}),
          scatter_kws=({'color':'yellow'}))
