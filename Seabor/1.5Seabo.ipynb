# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
a = sns.load_dataset('flights')
sns.relplot(x='passengers', y='month', data=a)

# %%
a = sns.load_dataset('flights')
sns.relplot(x='passengers',hue='year', y='month', data=a)

# %%
b = sns.load_dataset('tips')
sns.relplot(x='time',y='tip',data=b, kind='line')

# %%
sns.catplot(x='day', y='total_bill',data=b)

# %%
sns.catplot(x='day', y='total_bill',data=b, kind='violin')

# %%
sns.catplot(x='day', y='total_bill',kind='boxen',data=b)

# %%
# from scipy import stats

# %%
c = np.random.normal(loc= 5, size = 100, scale=2)

# %%
sns.distplot(c)
# Out:
# c:\python 39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
a = sns.load_dataset('iris')
b= sns.FacetGrid(a, col = 'species')
b.map(plt.hist, 'sepal_length')

# %%
a = sns.load_dataset('flights')
b= sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style ='dark')
a = sns.load_dataset('flights')
b= sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style='white', color_codes=True)
a=sns.load_dataset('tips')
sns.boxplot(x='day', y='total_bill',data=a)
sns.despine(offset=10, trim=True)

# %%
c= sns.color_palette()
c
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %%
 df = pd.read_csv('BSE.csv')

# %%
df
# Out:
#          Year No. of cos. Listed  No. of Securities Traded  No. of Trades  \
# 0   2021-2022               5504                    453525      380530373
# 1   2020-2021               5478                    791520      550075513
# 2   2019-2020               5378                    715092      324755136
# 3   2018-2019               5262                    733503      314522838
# 4   2017-2018               5619                    752003      358582337
# 5   2016-2017               5834                    753710      391850125
# 6   2015-2016               5911                    740029      411688690
# 7   2014-2015               5624                    771374      711066890
# 8   2013-2014               5336                    671507      363210584
# 9   2012-2013               5211                    752325      323508501
# 10  2011-2012               5133                    744742      394395405
# 11  2010-2011               5067                    776168      528469400
# 12  2009-2010               4975                    692507      605587554
# 13  2008-2009               4929                    644592      540798268
# 14  2007-2008               4887                    692993      530340315
# 15  2006-2007               4821                    640676      346221521
# 16  2005-2006               4781                    639289      264006644
# 17  2004-2005               4731                    546418      237410469
# 18  2003-2004               5528                    493506      202797719
# 19  2002-2003               5650                    421323      141308272
# 20  2001-2002               5782                    347724      127721555
# 21  2000-2001               5955                    397820      145637654
# 22  1999-2000               5889                    512629       74074784
# 23  1998-1999               5848                    343254       32624112
# 24  1997-1998                  -                    155891        8838644
#
#     Shares Traded  Turnover (Rs. Cr.)  Average Turnover  Average Trade Size  \
# 0            7658           710896.67         101556.67               18682
# 1           10456          1045089.56          87090.80               19000
# 2            5587           660896.03          55074.67               20351
# 3            5181           775590.08          64632.51               24660
# 4            7716          1082968.21          90247.35               30202
# 5            7072           998260.58          83188.38               25476
# 6            7625           740088.59          61674.05               17977
# 7            8568           854844.29          71237.02               12022
# 8            4799           521664.20          43472.02               14363
# 9            5672           548774.44          45731.20               16964
# 10           6541           667497.58          55624.80               16925
# 11           9908          1105026.89          92085.57               20910
# 12          11365          1378809.32         114900.78               22769
# 13           7396          1100073.77          91672.81               20342
# 14           9860          1578855.41         131571.28               29771
# 15           5608           956189.11          79682.43               27618
# 16           6645           816084.70          68007.06               30912
# 17           4772           518715.65          43226.30               21849
# 18           3904           502618.38          41884.87               24785
# 19           2214           314073.13          26172.76               22227
# 20           1821           307297.77          25608.15               24060
# 21           2579          1000032.62          83336.05               68666
# 22           2102           686428.55          57202.38               92667
# 23           1186           284636.87          23719.74               87248
# 24            371            86899.16          17379.83               98318
#
#     No. of Trading Days  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0                   126         NaN          NaN          NaN          NaN
# 1                   249         NaN          NaN          NaN          NaN
# 2                   247         NaN          NaN          NaN          NaN
# 3                   248         NaN          NaN          NaN          NaN
# 4                   246         NaN          NaN          NaN          NaN
# 5                   248         NaN          NaN          NaN          NaN
# 6                   247         NaN          NaN          NaN          NaN
# 7                   243         NaN          NaN          NaN          NaN
# 8                   251         NaN          NaN          NaN          NaN
# 9                   250         NaN          NaN          NaN          NaN
# 10                  249         NaN          NaN          NaN          NaN
# 11                  255         NaN          NaN          NaN          NaN
# 12                  244         NaN          NaN          NaN          NaN
# 13                  243         NaN          NaN          NaN          NaN
# 14                  251         NaN          NaN          NaN          NaN
# 15                  249         NaN          NaN          NaN          NaN
# 16                  251         NaN          NaN          NaN          NaN
# 17                  253         NaN          NaN          NaN          NaN
# 18                  254         NaN          NaN          NaN          NaN
# 19                  251         NaN          NaN          NaN          NaN
# 20                  247         NaN          NaN          NaN          NaN
# 21                  251         NaN          NaN          NaN          NaN
# 22                  252         NaN          NaN          NaN          NaN
# 23                  224         NaN          NaN          NaN          NaN
# 24                   97         NaN          NaN          NaN          NaN
#
#     Unnamed: 13
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN

# %%
df.dropna(how='all', axis=1, inplace=True)

# %%
df.head()
# Out:
#         Year No. of cos. Listed  No. of Securities Traded  No. of Trades  \
# 0  2021-2022               5504                    453525      380530373
# 1  2020-2021               5478                    791520      550075513
# 2  2019-2020               5378                    715092      324755136
# 3  2018-2019               5262                    733503      314522838
# 4  2017-2018               5619                    752003      358582337
#
#    Shares Traded  Turnover (Rs. Cr.)  Average Turnover  Average Trade Size  \
# 0           7658           710896.67         101556.67               18682
# 1          10456          1045089.56          87090.80               19000
# 2           5587           660896.03          55074.67               20351
# 3           5181           775590.08          64632.51               24660
# 4           7716          1082968.21          90247.35               30202
#
#    No. of Trading Days
# 0                  126
# 1                  249
# 2                  247
# 3                  248
# 4                  246

# %%
df = pd.read_excel('KPMG_VI_New_raw_data_update_final.xlsx', sheet_name='Transactions',  header=1, usecols='A:M')
df2 = pd.read_excel('Analysed_KPMG_VI_New_raw_data_update_final.xlsx', sheet_name='CustomerDemographic', usecols='A:M')

# %%
df2.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB   Age  \
# 0                                   93 1953-10-12  67.0
# 1                                   81 1980-12-16  40.0
# 2                                   61 1954-01-20  67.0
# 3                                   33 1961-10-03  59.0
# 4                                   56 1977-05-13  44.0
#
#                 job_title job_industry_category     wealth_segment  \
# 0     Executive Secretary                Health      Mass Customer
# 1  Administrative Officer    Financial Services      Mass Customer
# 2      Recruiting Manager              Property      Mass Customer
# 3                     NaN                    IT      Mass Customer
# 4           Senior Editor                   NaN  Affluent Customer
#
#   deceased_indicator owns_car  tenure
# 0                  N      Yes    11.0
# 1                  N      Yes    16.0
# 2                  N      Yes    15.0
# 3                  N       No     7.0
# 4                  N      Yes     8.0

# %% [markdown]
# ## Line plot

# %% [markdown]
# # 1

# %%
a = sns.lineplot(y='wealth_segment', x='past_3_years_bike_related_purchases', data=df2)

# %% [markdown]
# # 2

# %%
a = sns.lineplot(x='wealth_segment', y='past_3_years_bike_related_purchases',hue='gender', data=df2)

# %% [markdown]
# # 3

# %%
a = sns.lineplot(x='wealth_segment', y='past_3_years_bike_related_purchases',hue='gender', style='gender', data=df2)

# %% [markdown]
# # 4

# %%
sns.set(rc={'figure.figsize':(12,10)})
a = sns.lineplot(y='wealth_segment', x='past_3_years_bike_related_purchases', data=df2, ci=False)

# %%
a = sns.lineplot(y='wealth_segment', x='past_3_years_bike_related_purchases', data=df2, ci=False, markers=True)

# %% [markdown]
# # 5

# %%
a = sns.lineplot(x='Age', y='past_3_years_bike_related_purchases',hue='wealth_segment', style='gender', ci=False,data=df2, markers=True)

# %% [markdown]
# ## Bar plot

# %% [markdown]
# # 1

# %%
ax = sns.barplot( y='past_3_years_bike_related_purchases',x='wealth_segment', data=df2)
df2[['past_3_years_bike_related_purchases','wealth_segment']].groupby('wealth_segment').agg({'past_3_years_bike_related_purchases':"mean"})
# Out:
#                    past_3_years_bike_related_purchases
# wealth_segment
# Affluent Customer                            48.847804
# High Net Worth                               47.287953
# Mass Customer                                49.728500

# %%
ax = sns.barplot( y='past_3_years_bike_related_purchases',x='wealth_segment',ci=False, data=df2)

# %%
ax = sns.barplot( y='past_3_years_bike_related_purchases',x='wealth_segment',hue='gender', data=df2,ci=False)

# %%
ax = sns.barplot( x='past_3_years_bike_related_purchases',y='wealth_segment',hue='gender', data=df2,ci=False, orient='h')

# %%
ax = sns.barplot( x='past_3_years_bike_related_purchases',y='wealth_segment',hue='gender', data=df2,ci=False, orient='h',color='green')

# %%
ax = sns.barplot( x='past_3_years_bike_related_purchases',y='wealth_segment',hue='gender', data=df2,ci=False, orient='h',color='#E8B6EE')

# %%
# cool way to pick colors
# http://htmlcolorcodes.com/color-picker/

# %% [markdown]
# ## Histogram

# %%
sns.distplot(df2['Age'].values, color='blue')
plt.title('Age density')
# Out:
# c:\python 39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Age density')

# %%
sns.distplot(df2['Age'].values, color='blue')
plt.title('Age density')
mean = df2['Age'].mean()
# plt.axvline(mean,.5,color='red')
plt.axvline(mean,color='red')
# Out:
# c:\python 39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
